# %%
n=int(input())
for i in range(0,n):
  for j in range(0,n):
    print("*",end="  ")
  print()
# Out:
# 3
# *  *  *
# *  *  *
# *  *  *

# %%
n=int(input())
for i in range(0,n):
  for j in range(i+1):
    print("*",end="  ")
  print()
# Out:
# 2
# *
# *  *

# %%
n=int(input())
for i in range(0,n):
      for j in range(i+1):
        if j%2==0:
          print("*",end=" ")
        else:
          print(j,end=" ")
      print()
# Out:
# 5
# *
# * 1
# * 1 *
# * 1 * 3
# * 1 * 3 *

# %%
n=int(input())
for i in range(1,n+1):
  if i==3:
    pass
  else:
     print(i,end=" ")
# Out:
# 5
# 1 2 4 5

# %%
n=int(input())
for i in range(i+1):
  for j in range(0,n):
    print("*",end="  ")
  print()
# Out:
# 3
# *  *  *
# *  *  *
# *  *  *
# *  *  *

# %%
n=int(input())
for i in range(0,n):
 for j in range(i+1):
    print("*",end="   ")
 print()
# Out:
# 5
# *
# *   *
# *   *   *
# *   *   *   *
# *   *   *   *   *

# %%
n=int(input())
for row in range(n):
 for col in range(n):
  ele=(max(row+1 ,col+1,n-row,n-col))
  print(ele,end=" ")
 print()
# Out:
# 5
# 5 5 5 5 5
# 5 4 4 4 5
# 5 4 3 4 5
# 5 4 4 4 5
# 5 5 5 5 5
